# %%
import numpy as np
import pandas as pd


np.random.seed(42)


n = 20


age = np.random.randint(18, 60, size=n)
salary = np.random.randint(30000, 120000, size=n)
department = np.random.choice(['HR', 'Engineering', 'Marketing', 'Sales'], size=n)
experience = np.random.randint(1, 40, size=n)
gender = np.random.choice(['Male', 'Female'], size=n)
names = ['John', 'Jane', 'Bob', 'Alice', 'Mike', 'Emily', 'Tom', 'Emma', 'Chris', 'Lucy',
         'David', 'Sarah', 'Paul', 'Olivia', 'Mark', 'Sophia', 'Ryan', 'Lily', 'Kevin', 'Grace']


name = np.random.choice(names, size=n)


data = pd.DataFrame({
    'Name': name,
    'Age': age,
    'Salary': salary,
    'Department': department,
    'Experience': experience,
    'Gender': gender
})


print(data)
# Out:
#      Name  Age  Salary   Department  Experience  Gender
# 0    Mark   56   97969           HR           7  Female
# 1    Paul   46   35311    Marketing           8    Male
# 2    John   32  113104    Marketing          35  Female
# 3     Tom   25   83707           HR          14    Male
# 4   Chris   38  115305           HR          17  Female
# 5    John   56   58693    Marketing          36  Female
# 6   Sarah   36  101932  Engineering           4    Male
# 7    Emma   40   55658        Sales           2  Female
# 8   David   28  114478           HR           6    Male
# 9   Kevin   28   48431        Sales           4  Female
# 10   Ryan   41   32747  Engineering          29    Male
# 11   Emma   53   89150  Engineering          18    Male
# 12    Bob   57   95725  Engineering          26  Female
# 13    Bob   41  114654           HR          34  Female
# 14   John   20   65773  Engineering          10    Male
# 15   Mike   39   97435           HR          36  Female
# 16   Lucy   19   86886  Engineering          14  Female
# 17    Tom   41   96803        Sales          31  Female
# 18  Chris   47   61551        Sales          15    Male
# 19    Tom   55   41394    Marketing           8    Male

# %%
print("First 5 rows of the dataset:")
print(data.head())
# Out:
# First 5 rows of the dataset:
#     Name  Age  Salary Department  Experience  Gender
# 0   Mark   56   97969         HR           7  Female
# 1   Paul   46   35311  Marketing           8    Male
# 2   John   32  113104  Marketing          35  Female
# 3    Tom   25   83707         HR          14    Male
# 4  Chris   38  115305         HR          17  Female

# %%
print("\nSummary statistics:")
print(data.describe())
# Out:
# Summary statistics:
#              Age         Salary  Experience
# count  20.000000      20.000000   20.000000
# mean   39.900000   80335.300000   17.700000
# std    11.968819   27926.923604   12.061684
# min    19.000000   32747.000000    2.000000
# 25%    31.000000   57934.250000    7.750000
# 50%    40.500000   88018.000000   14.500000
# 75%    48.500000   98959.750000   29.500000
# max    57.000000  115305.000000   36.000000

# %%
print("\nData types and non-null counts:")
print(data.info())
# Out:
# Data types and non-null counts:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        20 non-null     object
#  1   Age         20 non-null     int32
#  2   Salary      20 non-null     int32
#  3   Department  20 non-null     object
#  4   Experience  20 non-null     int32
#  5   Gender      20 non-null     object
# dtypes: int32(3), object(3)
# memory usage: 852.0+ bytes
# None

# %%
print("\nMissing values:")
print(data.isnull().sum())
# Out:
# Missing values:
# Name          0
# Age           0
# Salary        0
# Department    0
# Experience    0
# Gender        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style="whitegrid")


plt.figure(figsize=(10, 6))
sns.histplot(data['Age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()


plt.figure(figsize=(10, 6))
sns.histplot(data['Salary'], bins=20, kde=True)
plt.title('Salary Distribution')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Salary', hue='Gender', data=data)
plt.title('Age vs. Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()


plt.figure(figsize=(10, 6))
sns.boxplot(x='Department', y='Salary', data=data)
plt.title('Salary by Department')
plt.xlabel('Department')
plt.ylabel('Salary')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data['Salary'])
plt.title('Box Plot of Salary')
plt.xlabel('Salary')
plt.show()

# %%
iris = sns.load_dataset('iris')

# %%
sns.set(style="whitegrid")


plt.figure(figsize=(10, 6))
sns.histplot(iris['sepal_length'], bins=20, kde=True, color='blue')
plt.title('Distribution of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()


plt.figure(figsize=(10, 6))
sns.histplot(iris['petal_width'], bins=20, kde=True, color='green')
plt.title('Distribution of Petal Width')
plt.xlabel('Petal Width (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
numeric_data = data.select_dtypes(include=['int64', 'float64'])


plt.figure(figsize=(8, 6))
corr = numeric_data.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))

# %%
import warnings
warnings.filterwarnings("ignore")


plt.figure(figsize=(8, 6))
corr = numeric_data.corr()


mask = np.triu(np.ones_like(corr, dtype=bool))

sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1, mask=mask)
plt.title('Correlation Heatmap')
plt.show()
